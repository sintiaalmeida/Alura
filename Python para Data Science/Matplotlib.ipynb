# %% [markdown]
# <a href="https://colab.research.google.com/github/sintiaalmeida/Alura/blob/main/Python%20para%20Data%20Science/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
notas_matematica = [8, 7, 7, 8, 9, 3, 2, 8]
x = list(range(1, 9))
y = notas_matematica
plt.plot(x, y, marker='o')
plt.title('Notas de Matemática')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()
